# %% [markdown]
# <a href="https://colab.research.google.com/github/vmjunior01/cd01/blob/main/Etapa07_Fase02_Robotica_cjovem_StandardScaler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unidecode
import pandas as pd
import joblib
import os
from sklearn.preprocessing import StandardScaler
from unidecode import unidecode  # Para remover acentos

# Lista de anos dos arquivos a serem processados
anos = [2023, 2024, 2025]

# Caminho base
caminho_base = '/content'

for ano in anos:
    nome_arquivo = f'df_coleta{ano}.z'
    caminho_arquivo = os.path.join(caminho_base, nome_arquivo)

    try:
        # Carregar o DataFrame
        df = joblib.load(caminho_arquivo)

        # Renomear colunas: minúsculas e sem acentos
        df.columns = [unidecode(col).lower() for col in df.columns]

        print(f"\nColunas no arquivo df_coleta{ano} após renomeação: {list(df.columns)}")

        # Verificação de colunas
        colunas_esperadas = ['peso', 'local', 'residuo']
        if not all(col in df.columns for col in colunas_esperadas):
            print(f"Colunas necessárias não encontradas no arquivo de {ano}. Pulando este.")
            continue

        # Mostrar primeiras linhas do DataFrame original
        print(f"\nPrimeiras linhas do df_coleta{ano} (original):")
        print(df.head())

        # Normalizar a coluna 'peso'
        scaler = StandardScaler()
        df['peso_normalizado'] = scaler.fit_transform(df[['peso']])

        # One-Hot Encoding nas colunas 'local' e 'residuo'
        df = pd.get_dummies(df, columns=['local', 'residuo'])

        # Mostrar primeiras linhas do DataFrame processado
        print(f"\nPrimeiras linhas do df_coleta{ano} (processado):")
        print(df.head())

        # Salvar em formato .z
        nome_saida_z = f'df_coleta_normalizada_{ano}.z'
        caminho_saida_z = os.path.join(caminho_base, nome_saida_z)
        joblib.dump(df, caminho_saida_z)

        # Salvar em formato .csv
        nome_saida_csv = f'df_coleta_normalizada_{ano}.csv'
        caminho_saida_csv = os.path.join(caminho_base, nome_saida_csv)
        df.to_csv(caminho_saida_csv, index=False)

        print(f"Arquivos df_coleta_normalizada_{ano}.z e .csv salvos com sucesso.")

    except Exception as e:
        print(f"Erro ao processar {nome_arquivo}: {e}")
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
#
# Colunas no arquivo df_coleta2023 após renomeação: ['data', 'mes', 'coleta', 'local', 'residuo', 'peso']
#
# Primeiras linhas do df_coleta2023 (original):
#         data        mes  coleta             local           residuo  peso
# 0 2023-01-04    Janeiro       1  Drone de Garagem     Impressora 3D  10.5
# 1 2023-01-04    Janeiro       1  Drone de Garagem      Caixa Drones   7.8
# 2 2023-01-25    Janeiro       2               JSB  Ferro e Plástico  13.1
# 3 2023-02-06  Fevereiro       3            Locmed             Placa  13.9
# 4 2023-02-06  Fevereiro       3            Locmed     Bateria Litio  33.1
#
# Primeiras linhas do df_coleta2023 (processado):
#         data        mes  coleta  peso  peso_normalizado  local_AJ Advogados  \
# 0 2023-01-04    Janeiro       1  10.5         -0.127423               False
# 1 2023-01-04    Janeiro       1   7.8         -0.132049               False
# 2 2023-01-25    Janeiro       2  13.1         -0.122968               False
# 3 2023-02-06  Fevereiro       3  13.9         -0.121598               False
# 4 2023-02-06  Fevereiro       3  33.1         -0.088702               False
#
#    local_Arco Educação  local_Banco Plamas  local_Cantinho \ndo Frango  \
# 0                False               False                       False
# 1                False               False                       False
# 2                False               False                       False
# 3                False               False                       False
# 4                False               False                       False
#
#    local_Cantinho do Frango  ...  residuo_Rolo de fio  \
# 0                     False  ...                False
# 1                     False  ...                False
# 2                     False  ...                False
# 3                     False  ...                False
# 4                     False  ...                False
#
#    residuo_Sacola Baterias  residuo_Som  residuo_TV  residuo_Teclado  \
# 0                    False        False       False            False
# 1                    False        False       False            False
# 2                    False        False       False            False
# 3                    False        False       False            False
# 4                    False        False       False            False
#
#    residuo_Teclado 18  residuo_Teclado e ferro  residuo_Telefones 6  \
# 0               False                    False                False
# 1               False                    False                False
# 2               False                    False                False
# 3               False                    False                False
# 4               False                    False                False
#
#    residuo_Ventilador  \
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
#
#    residuo_teclado + fones + ocúlos 3d +mouse + fios + extensão
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 118 columns]
# Arquivos df_coleta_normalizada_2023.z e .csv salvos com sucesso.
#
# Colunas no arquivo df_coleta2024 após renomeação: ['data', 'mes', 'coleta', 'local', 'residuo', 'peso']
#
# Primeiras linhas do df_coleta2024 (original):
#         data      mes  coleta                 local       residuo   peso
# 0 2024-01-03  Janeiro       1               Nidobox  Desconhecido  179.8
# 1 2024-01-05  Janeiro       2    EPP Joaquim Albano  Desconhecido   72.7
# 2 2024-01-05  Janeiro       3  Transforme Coworking  Desconhecido   16.2
# 3 2024-01-11  Janeiro       4        Linhas e Cores  Desconhecido   69.3
# 4 2024-01-11  Janeiro       5                Cequip  Desconhecido   50.4
#
# Primeiras linhas do df_coleta2024 (processado):
#         data      mes  coleta   peso  peso_normalizado  local_4 doadores  \
# 0 2024-01-03  Janeiro       1  179.8         -0.181208             False
# 1 2024-01-05  Janeiro       2   72.7         -0.264593             False
# 2 2024-01-05  Janeiro       3   16.2         -0.308582             False
# 3 2024-01-11  Janeiro       4   69.3         -0.267240             False
# 4 2024-01-11  Janeiro       5   50.4         -0.281955             False
#
#    local_A2Pro Nailton Doador De Resíduos  local_ALECE  \
# 0                                   False        False
# 1                                   False        False
# 2                                   False        False
# 3                                   False        False
# 4                                   False        False
#
#    local_Aluno Unifametro  local_Aço Cearense  ...  local_São José  \
# 0                   False               False  ...           False
# 1                   False               False  ...           False
# 2                   False               False  ...           False
# 3                   False               False  ...           False
# 4                   False               False  ...           False
#
#    local_TECER  local_Termaco logística  local_Transforme Coworking  \
# 0        False                    False                       False
# 1        False                    False                       False
# 2        False                    False                        True
# 3        False                    False                       False
# 4        False                    False                       False
#
#    local_UFC  local_Unifametro  local_VIPER  local_Vapt Vupt  local_WAP  \
# 0      False             False        False            False      False
# 1      False             False        False            False      False
# 2      False             False        False            False      False
# 3      False             False        False            False      False
# 4      False             False        False            False      False
#
#    residuo_Desconhecido
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
#
# [5 rows x 79 columns]
# Arquivos df_coleta_normalizada_2024.z e .csv salvos com sucesso.
#
# Colunas no arquivo df_coleta2025 após renomeação: ['data', 'mes', 'coleta', 'local', 'residuo', 'peso']
#
# Primeiras linhas do df_coleta2025 (original):
#         data      mes  coleta          local       residuo   peso
# 0 2025-01-02  Janeiro       1        C Rolim  Desconhecido  95.24
# 1 2025-01-03  Janeiro       2       Cartório  Desconhecido  26.40
# 2 2025-01-07  Janeiro       3         Locmed  Desconhecido  38.22
# 3 2025-01-07  Janeiro       3         Cequip  Desconhecido  20.66
# 4 2025-01-07  Janeiro       3  Doador Avulso  Desconhecido  33.96
#
# Primeiras linhas do df_coleta2025 (processado):
#         data      mes  coleta   peso  peso_normalizado  local_ALECE  \
# 0 2025-01-02  Janeiro       1  95.24         -0.275475        False
# 1 2025-01-03  Janeiro       2  26.40         -0.437758        False
# 2 2025-01-07  Janeiro       3  38.22         -0.409893        False
# 3 2025-01-07  Janeiro       3  20.66         -0.451289        False
# 4 2025-01-07  Janeiro       3  33.96         -0.419936        False
#
#    local_Antares  local_Assefaz  local_Assembleia  local_Autocore  ...  \
# 0          False          False             False           False  ...
# 1          False          False             False           False  ...
# 2          False          False             False           False  ...
# 3          False          False             False           False  ...
# 4          False          False             False           False  ...
#
#    local_Shopping Aldeota  local_Singular  local_Sorvete  local_Taiba Carmel  \
# 0                   False           False          False               False
# 1                   False           False          False               False
# 2                   False           False          False               False
# 3                   False           False          False               False
# 4                   False           False          False               False
#
#    local_Transforme  local_Transforme Coworking  local_VIPER  \
# 0             False                       False        False
# 1             False                       False        False
# 2             False                       False        False
# 3             False                       False        False
# 4             False                       False        False
#
#    local_Vapt Vupt Rio Mar  local_WAP  residuo_Desconhecido
# 0                    False      False                  True
# 1                    False      False                  True
# 2                    False      False                  True
# 3                    False      False                  True
# 4                    False      False                  True
#
# [5 rows x 74 columns]
# Arquivos df_coleta_normalizada_2025.z e .csv salvos com sucesso.
